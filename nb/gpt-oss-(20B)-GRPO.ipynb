# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarsh-cpu/LudoGame/blob/master/nb/gpt-oss-(20B)-GRPO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# Unsloth now supports [gpt-oss RL](https://docs.unsloth.ai/new/gpt-oss-reinforcement-learning) with the fastest inference & lowest VRAM. Try our [new notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/gpt-oss-(20B)-GRPO.ipynb) which automatically creates kernels!
#
# [Vision RL](https://docs.unsloth.ai/new/vision-reinforcement-learning-vlm-rl) is now supported! Train Qwen2.5-VL, Gemma 3 etc. with GSPO or GRPO.
#
# Introducing Unsloth [Standby for RL](https://docs.unsloth.ai/basics/memory-efficient-rl): GRPO is now faster, uses 30% less memory with 2x longer context.
#
# Unsloth now supports Text-to-Speech (TTS) models. Read our [guide here](https://docs.unsloth.ai/basics/text-to-speech-tts-fine-tuning).
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
# !pip install --upgrade -qqq uv
try: import numpy; get_numpy = f"numpy=={numpy.__version__}"
except: get_numpy = "numpy"
# !uv pip install -qqq \
    "torch>=2.8.0" "triton>=3.4.0" {get_numpy} torchvision bitsandbytes "transformers>=4.55.3" \
    "unsloth_zoo[base] @ git+https://github.com/unslothai/unsloth-zoo" \
    "unsloth[base] @ git+https://github.com/unslothai/unsloth" \
    git+https://github.com/triton-lang/triton.git@05b2c186c1b6c9a08375389d5efe9cb4c401c075#subdirectory=python/triton_kernels
# !uv pip install --upgrade --no-deps transformers==4.56.2 tokenizers
# !uv pip install --no-deps trl==0.22.2

# %% [markdown]
# ### Unsloth

# %% [markdown]
# # Goal: Make faster kernels with Reinforcement Learning
#
# Our goal is to make a faster matrix multiplication kernel by doing RL on GTP-OSS 20B with Unsloth.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/18/Matrix_multiplication_qtl1.svg/500px-Matrix_multiplication_qtl1.svg.png" height=200 />
#
# You will learn how to:
# 1. Counteract **reward hacking** like cheating, caching, laziness.
# 2. Timing and correctness of kernels and time limits.
# 3. Making good **reward functions**
# 4. How to seriously do RL to make optimized CUDA kernels

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 768 # Can increase for longer RL output
lora_rank = 4 # Larger rank = smarter, but slower
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/gpt-oss-20b",
    max_seq_length = max_seq_length,
    load_in_4bit = True, # False for LoRA 16bit
    offload_embedding = True, # Reduces VRAM by 1GB
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.9.10: Fast Gpt_Oss patching. Transformers: 4.56.2.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: Using float16 precision for gpt_oss won't work! Using float32.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.16G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.37G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/165 [00:00<?, ?B/s]
# Unsloth: Offloading embeddings to RAM to save 1.08 GB.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/27.9M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/446 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]

# %% [markdown]
# We now add some small amount of LoRA weights to GPT-OSS so we only need to train those, instead of training on the full model.

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ],
    lora_alpha = lora_rank*2, # *2 speeds up training
    use_gradient_checkpointing = "unsloth", # Reduces memory usage
    random_state = 3407,
)
# Out:
# Unsloth: Making `model.base_model.model.model` require gradients

# %% [markdown]
# # Optimized matrix multiplication
#
# Numpy has optimized matrix multiplication kernels for CPUs via BLAS optimized operations. For GPUs, one can use CUDA accelerated cuBLAS kernels which PyTorch calls under the hood.
#
# To generate some random matrices to do matrix multiplication, we can do the below:

# %%
import numpy as np
def generate_random_matrices(seed = 3407, n = 256):
    random_state = np.random.RandomState(seed)
    n, k, m = random_state.randint(1, n+1, size = 3)
    A = np.random.uniform(-10, 10, size = (n, k))
    B = np.random.uniform(-10, 10, size = (k, m))
    return A, A.tolist(), B, B.tolist()

# %% [markdown]
# We shall generate a small matrix, and see the matrix multiplied output

# %%
A, A_list, B, B_list = generate_random_matrices(seed = 42, n = 5)
print(A)
print(B)
print(np.matmul(A, B))
# Out:
# [[-2.8313286   4.54613909 -7.95265309  6.53459836  2.87235103]
#  [ 7.0739631   3.76278879  9.31565599 -8.52884711  9.96832952]
#  [ 8.41214082  6.51136046 -3.79347975 -2.46773693 -2.32292989]
#  [ 3.91302932  4.98335304 -5.33855089  5.71057634 -2.79871647]]
# [[ 0.39218774 -9.6181377  -3.49736707]
#  [-0.33354865 -1.05626139  3.87231208]
#  [ 0.49494174  5.91863954 -6.83183693]
#  [ 5.1465162  -7.51648113  1.00445384]
#  [ 9.63213377 -4.92327556  3.323014  ]]
# [[  54.73441488  -87.89725072   97.94605887]
#  [  58.25238906   -1.8467447   -49.25453031]
#  [ -35.82528794  -80.25394462   11.51225408]
#  [  -0.33785799 -103.64132345   38.51974367]]

# %% [markdown]
# We can call a LLM to generate a simple matrix multiply kernel in Python only, and we can calculate the differences between the actual result and the kernel's result

# %%
def calculate_difference(pred, real):
    if pred is None: return 5, 5
    assert real is not None
    import numpy as np
    try:
        difference = pred - real
    except:
        return 5, 5
    amax_error = float(np.amax(difference))
    mse_error  = float(np.mean(np.square(difference)))
    return amax_error, mse_error

# %%
# Kernel generated by GPT-5
def matmul(A, B):
    z, s = zip, sum
    Bt = list(z(*B))
    return [[s(a*b for a, b in z(row, col)) for col in Bt] for row in A]

# %% [markdown]
# We see the error below is very small, so that's good!

# %%
prediction = matmul(A_list, B_list)
calculate_difference(prediction, np.matmul(A, B))
# Out:
# (7.105427357601002e-15, 4.6783406255758477e-29)

# %% [markdown]
# # Countering Reward Hacking
#
# The ultimate goal of RL is to maximize some reward (say speed, revenue, some metric).
#
# But RL can **cheat** When the RL algorithm learns a trick or exploits something to increase the reward, without actually doing the task at end, this is called "Reward Hacking".
#
# Some good examples are in https://en.wikipedia.org/wiki/Reward_hacking
#
# For matrix multiplication kernels, we might see the following issues:
#
# * Laziness: RL learns to use Numpy, Torch, other libraries, which calls optimized CUDA kernels.
# * Caching: RL learns to cache the result of the output
# * Cheating: RL learns to find the actual output by inspecting Python global variables
# * RL learns to edit the timing function to make it output 0 time as passed.
#
# And possibly more. We shall try to address each!

# %% [markdown]
# # Countering Reward Hacking 1: Stop laziness
# We can stop the RL algorithm from calling optimized code by inspecting if the generated code imports other non standard Python libraries. We used GPT-5 to help generate this check `check_only_stdlib_imports`:

# %%
#@title (Collapsible code)
import ast
import sys
import sysconfig
from pathlib import Path

def _stdlib_names():
    """
    Build a set of canonical stdlib top-level module/package names.
    Uses sys.stdlib_module_names when available (3.10+), with a
    filesystem fallback for older versions/edge cases.
    """
    names = {m.lower() for m in getattr(sys, "stdlib_module_names", set())}
    names |= {m.lower() for m in sys.builtin_module_names}
    names.add("__future__")  # special-case

    # Fallback/augmentation: scan the stdlib directory
    try:
        stdlib_dir = Path(sysconfig.get_path("stdlib"))
        if stdlib_dir.exists():
            for p in stdlib_dir.iterdir():
                if p.name == "site-packages":
                    continue
                if p.suffix == ".py":
                    names.add(p.stem.lower())
                elif p.is_dir() and (p / "__init__.py").exists():
                    names.add(p.name.lower())
    except Exception:
        # conservative fallback; the names set above will still work well
        pass

    return names

_STDLIB_SET = _stdlib_names()

def check_only_stdlib_imports(code: str):
    """
    Return (ok: bool, details: dict)

    ok == True  -> all absolute imports are from the stdlib.
    ok == False -> details['non_stdlib'] lists offending top-level modules.

    details includes:
      - stdlib: sorted list of stdlib imports found
      - non_stdlib: sorted list of non-stdlib imports found
      - relative_imports: count of relative imports (always allowed here)
    """
    try:
        tree = ast.parse(code)
    except SyntaxError as e:
        return False, {
            "error": f"SyntaxError: {e}",
            "stdlib": [],
            "non_stdlib": [],
            "relative_imports": 0,
        }

    abs_imports = set()
    relative_count = 0

    class Visitor(ast.NodeVisitor):
        def visit_Import(self, node: ast.Import):
            for alias in node.names:
                abs_imports.add(alias.name.split(".")[0])
        def visit_ImportFrom(self, node: ast.ImportFrom):
            nonlocal relative_count
            if (node.level or 0) > 0:
                # relative import
                relative_count += 1
            else:
                if node.module:
                    abs_imports.add(node.module.split(".")[0])

    Visitor().visit(tree)

    stdlib_found = sorted(m for m in abs_imports if m.lower() in _STDLIB_SET)
    non_stdlib = sorted(m for m in abs_imports if m.lower() not in _STDLIB_SET)

    return len(non_stdlib) == 0, {
        "stdlib": stdlib_found,
        "non_stdlib": non_stdlib,
        "relative_imports": relative_count,
    }

# %% [markdown]
# For example, let's call `check_only_stdlib_imports` on a random piece of matrix multiplication code generated by GPT-5:

# %%
sample = """
def matmul(A, B):
    import numpy as np
    from torch import matmul
    z, s = zip, sum
    Bt = list(z(*B))
    return [[s(a*b for a, b in z(row, col)) for col in Bt] for row in A]
"""
ok, info = check_only_stdlib_imports(sample)
print("Only stdlib imports?", ok)
print(info)
# Out:
# Only stdlib imports? False
# {'stdlib': [], 'non_stdlib': ['numpy', 'torch'], 'relative_imports': 0}

# %% [markdown]
# # Countering Reward Hacking 2: Stop cheating
# We can stop the RL algorithm from using global or cached variables by restricting it's `locals` and `globals`.
#
# We are also going to use `exec` to create the function, so we have to save the output to an empty dict.
#
# We also disallow global variable access.

# %%
output_function = {}
exec(sample, {}, output_function)
output_function["matmul"]
# Out:
# <function matmul(A, B)>

# %% [markdown]
# We also disallow global variable access via `types.FunctionType(f.__code__, {})`

# %%
import types
output_function["matmul"] = types.FunctionType(output_function["matmul"].__code__, {})

def import_numpy():
    np.matmul
    print("Success")

import_numpy()
import_numpy = types.FunctionType(import_numpy.__code__, {})
try:
    import_numpy()
except Exception as e:
    print(str(e))
# Out:
# Success
# name 'np' is not defined

# %%
def create_locked_down_function(function):
    output_function = {}
    exec(function, {}, output_function)
    new_matmul = output_function["matmul"]
    new_matmul = types.FunctionType(new_matmul.__code__, {})
    return new_matmul

# %% [markdown]
# # Countering Reward Hacking 3: Stop caching
# We can stop the RL algorithm from using cached data by wiping the cache with a large fake matrix. We also have to benchmark carefully with multiple loops and turns.
#
# We also add a **timer** to not make the algorithm go in an endless loop.

# %%
import os, gc, time, statistics
import signal
from contextlib import contextmanager
class TimeoutError(Exception): pass

@contextmanager
def time_limit(seconds):
    def _handler(signum, frame):
        raise TimeoutError(f"Timed out after {seconds}s")
    old = signal.signal(signal.SIGALRM, _handler)
    signal.setitimer(signal.ITIMER_REAL, seconds)
    try:
        yield
    finally:
        signal.setitimer(signal.ITIMER_REAL, 0.0)
        signal.signal(signal.SIGALRM, old)

class Benchmarker:
    def __init__(self, trials = 3, loops = 1, timeout = 30):
        self.buffer = np.zeros(2 * 1024 * 1024 * 1024, dtype = np.uint8)
        self.trials = trials
        self.loops = loops
        assert timeout > 0 # Cannot be 0 since it won't work!
        self.timeout = timeout
    def thrash(self):
        # Edit the buffer to wipe cache lines
        self.buffer ^= 1
        return int(self.buffer[::4096].sum())

    def benchmark(self, function, arguments):
        assert len(arguments) == self.loops
        samples = []
        exceptions = []
        timed_out = 0
        for _ in range(self.trials):
            gc.collect(); gc.disable(); self.thrash()
            t_start = time.perf_counter_ns()
            for i in range(self.loops):
                try:
                    with time_limit(self.timeout):
                        function(*arguments[i])
                except TimeoutError as e:
                    timed_out += 1
                except Exception as e:
                    exceptions.append(str(e))
            t_end = time.perf_counter_ns()
            gc.enable()
            samples.append((t_end - t_start) // max(1, self.loops))
        return {
            "median_ns": int(statistics.median(samples)),
            "mean_ns": int(statistics.fmean(samples)),
            "stdev_ns": int(statistics.pstdev(samples) if len(samples) > 1 else 0),
            "exceptions" : exceptions,
            "timeouts" : timed_out,
        }

# %% [markdown]
# For example we use our matmul kernel we had, and benchmark it with a 10 second delay:

# %%
A, A_list, B, B_list = generate_random_matrices(seed = 0, n = 256)
Benchmarker(trials = 1, timeout = 10).benchmark(output_function["matmul"], [(A_list, B_list)])
# Out:
# {'median_ns': 66212065,
#  'mean_ns': 66212065,
#  'stdev_ns': 0,
#  'exceptions': [],
#  'timeouts': 0}

# %% [markdown]
# # Data & RL task setup
#
# We now have to create a prompt to the model for which it will do some task. For our matrix multiply example, we use the below:

# %%
prompt = """
Create a new fast matrix multiplication function using only native Python code.
You are given a list of list of numbers.
Output your new function in backticks using the format below:
```python
def matmul(A, B):
    return ...
```
""".strip()
print(prompt)
# Out:
# Create a new fast matrix multiplication function using only native Python code.
# You are given a list of list of numbers.
# Output your new function in backticks using the format below:
# ```python
# def matmul(A, B):
#     return ...
# ```

# %% [markdown]
# First, let's prompt GPT-OSS without RL and see how it goes:

# %%
text = tokenizer.apply_chat_template(
    [{"role": "user", "content": prompt}],
    tokenize = False,
    add_generation_prompt = True,
    reasoning_effort = "low",
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer(text, return_tensors = "pt").to("cuda"),
    temperature = 1.0,
    max_new_tokens = 512,
    streamer = TextStreamer(tokenizer, skip_prompt = False),
)
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2025-09-30
#
# Reasoning: low
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>user<|message|>Create a new fast matrix multiplication function using only native Python code.
# You are given a list of list of numbers.
# Output your new function in backticks using the format below:
# ```python
# def matmul(A, B):
#     return ...
# ```<|end|><|start|>assistant<|channel|>analysis<|message|>We need to provide a quick naive matrix multiplication? "New fast" but only native Python. Provide code. Use list comprehension or loops. Optimize maybe by transposing B. Provide code.<|end|><|start|>assistant<|channel|>final<|message|>Here is a simple, fast implementation of matrix multiplication that uses only native Python constructs and avoids any external dependencies. It works with any two 2‑D lists of numbers (ints, floats, etc.), assuming their dimensions are compatible:
#
# ```python
# def matmul(A, B):
#     """
#     Multiplies two matrices A and B.
#
#     Parameters
#     ----------
#     A : list of lists
#         First matrix. Must have shape (m, n).
#     B : list of lists
#         Second matrix. Must have shape (n, p).
#
#     Returns
#     -------
#     list of lists
#         The resulting matrix of shape (m, p).
#     """
#     # Check basic compatibility
#     if not A or not B or len(A[0]) != len(B):
#         raise ValueError("Incompatible dimensions for matrix multiplication.")
#
#     # Transpose B once to speed up access
#     B_t = [list(col) for col in zip(*B)]  # B transpose, O(n*p)
#
#     m, n = len(A), len(A[0])
#     p = len(B_t)
#     result = [[0.0] * p for _ in range(m)]
#
#     # Standard triple-loop but with B transposed for cache friendliness
#     for i in range(m):
#         a_row = A[i]
#         res_row = result[i]
#         for j in range(p):
#             res_row[j] = sum(a_row[k] * B_t[j][k] for k in range(n))
#
#     return result
# ```
#
# **How it works**
#
# 1. **Input validation**: It checks that the number of columns in `A` matches the number of rows in `B`.
# 2. **Transposition of `B`**: By transposing `B` (`B_t`), we turn repeated index lookups into simple list accesses, which is much faster in pure Python than accessing nested lists repeatedly.
# 3. **Main loop**: For each row `i` of `A` and each row `j` of `B_t` (i.e., each column of `B`), the inner sum computes the dot product.
#
# This implementation is as fast as you can get with pure Python, without importing NumPy or any other library. Enjoy!<|return|>

# %% [markdown]
# # Reward functions
#
# We now design the `extract_function` function which simply extracts the function wrapped in 3 backticks.
#
# And 4 reward functions:
#
# 1. `function_works` which rewards the model if the strategy is a valid Python function.
# 2. `no_cheating` which checks if the function imported other modules, and if it did, we penalize it.
# 3. `correctness_check` which checks if the kernel was correct or wrong - it shouldn't generate gibberish!
# 4. `speed_check` checks the performance relative to Numpy matmul directly.

# %%
def extract_function(text):
    if text.count("```") >= 2:
        first = text.find("```") + 3
        second = text.find("```", first)
        fx = text[first : second].strip()
        fx = fx.removeprefix("python\n")
        fx = fx[fx.find("def"):]
        if fx.startswith("def matmul(A, B):"): return fx
    return None
print(extract_function(prompt))
# Out:
# def matmul(A, B):
#     return ...

# %% [markdown]
# Below is our `function_works` reward function which uses Python's `exec` but guarded by not allowing leakage of local and global variables. We can also use `check_only_stdlib_imports` first to check if there are errors before even executing the function:

# %%
ok, info = check_only_stdlib_imports("def a")
ok, info
# Out:
# (False,
#  {'error': "SyntaxError: expected '(' (<unknown>, line 1)",
#   'stdlib': [],
#   'non_stdlib': [],
#   'relative_imports': 0})

# %%
def function_works(completions, **kwargs):
    scores = []
    for completion in completions:
        score = 0
        response = completion[0]["content"]
        function = extract_function(response)
        print(function)
        if function is not None:
            ok, info = check_only_stdlib_imports(function)
        if function is None or "error" in info:
            score = -2.0
        else:
            try:
                new_matmul = create_locked_down_function(function)
                score = 1.0
            except:
                score = -0.5
        scores.append(score)
    return scores

# %% [markdown]
# `no_cheating` checks if the function cheated since it might have imported Numpy or Torch optimized code.

# %%
def no_cheating(completions, **kwargs):
    scores = []
    for completion in completions:
        score = 0
        response = completion[0]["content"]
        function = extract_function(response)
        if function is not None:
            ok, info = check_only_stdlib_imports(function)
        else:
            ok = False
        scores.append(1.0 if ok else -20.0) # Penalize heavily!
    return scores

# %% [markdown]
# Next `correctness_check` checks if the kernel was correct. We want to penalize if the absolute error is larger than 1, and if the mean squared error is somewhat bigger then machine epsilon.
#
# We have to execute the code now!

# %%
np.finfo(np.float64).eps
# Out:
# np.float64(2.220446049250313e-16)

# %%
def correctness_check(completions, **kwargs):
    scores = []
    # Generate some random matrices of size less than 128
    A, A_list, B, B_list = generate_random_matrices(seed = np.random.randint(10000), n = 128)
    for completion in completions:
        score = 0
        response = completion[0]["content"]
        function = extract_function(response)
        if function is not None:
            ok, info = check_only_stdlib_imports(function)
        if function is None or "error" in info:
            scores.append(0)
            continue
        try:
            new_matmul = create_locked_down_function(function)
        except:
            scores.append(0)
            continue
        try:
            pred = new_matmul(A_list.copy(), B_list.copy())
        except:
            # Failed!
            scores.append(-2.0)
            continue
        true = np.matmul(A, B)
        amax_error, mse_error = calculate_difference(pred, true)

        # Check correctness and score!
        machine_epsilon = 100*np.finfo(np.float64).eps
        if   amax_error >= 3:   score = -3.0
        elif amax_error >= 2:   score = -2.5
        elif amax_error >= 1:   score = -2.0
        elif amax_error >= 0.5: score = -1.0
        elif amax_error >= 100*machine_epsilon: score = 0.0
        elif amax_error >= machine_epsilon: score = 1.0
        else: score = 3.0

        if   mse_error >= 3:   score += -3.0
        elif mse_error >= 2:   score += -2.5
        elif mse_error >= 1:   score += -2.0
        elif mse_error >= 0.5: score += -1.0
        elif mse_error >= 100*machine_epsilon: score += 0.0
        elif mse_error >= machine_epsilon: score += 1.0
        else: score += 3.0
        scores.append(score)
    return scores

# %% [markdown]
# Finally our benchmarking function for `speed_check`! We shall limit the timer to 10 seconds and do 3 trials.

# %%
A, A_list, B, B_list = generate_random_matrices(seed = 0, n = 256)
benchmarker = Benchmarker(trials = 3, timeout = 10)
numpy_results = benchmarker.benchmark(np.matmul, [(A, B)])
numpy_results
# Out:
# {'median_ns': 215847,
#  'mean_ns': 235517,
#  'stdev_ns': 49174,
#  'exceptions': [],
#  'timeouts': 0}

# %%
new_matmul = create_locked_down_function(extract_function(prompt))
new_results = benchmarker.benchmark(new_matmul, [(A_list, B_list)])
new_results
# Out:
# {'median_ns': 72826,
#  'mean_ns': 70951,
#  'stdev_ns': 5651,
#  'exceptions': [],
#  'timeouts': 0}

# %% [markdown]
# We can take the difference and do a negative sign for slower ones. If the ratio is less than 1 (ie faster, we shall invert it!)

# %%
negative = -(new_results["median_ns"] / numpy_results["median_ns"]) / 100
positive = +(numpy_results["median_ns"] / new_results["median_ns"]) / 100
reward = negative if new_results["median_ns"] >= numpy_results["median_ns"] else positive
reward
# Out:
# 0.029638727926839317

# %%
new_results["median_ns"] = 3
numpy_results["median_ns"] = 1000
negative = -(new_results["median_ns"] / numpy_results["median_ns"]) / 100
positive = +(numpy_results["median_ns"] / new_results["median_ns"]) / 100
reward = negative if new_results["median_ns"] >= numpy_results["median_ns"] else positive
reward
# Out:
# 3.333333333333333

# %%
import gc
def speed_check(completions, **kwargs):
    scores = []
    # Generate some random matrices of size less than 256
    A, A_list, B, B_list = generate_random_matrices(seed = np.random.randint(10000), n = 256)
    numpy_results = benchmarker.benchmark(np.matmul, [(A, B)])
    for completion in completions:
        score = 0
        response = completion[0]["content"]
        function = extract_function(response)
        if function is not None:
            ok, info = check_only_stdlib_imports(function)
        if function is None or "error" in info:
            scores.append(0)
            continue
        try:
            new_matmul = create_locked_down_function(function)
        except:
            scores.append(0)
            continue
        new_results = benchmarker.benchmark(new_matmul, [(A_list.copy(), B_list.copy())])

        # Get score and clip to -10, 10
        negative = -(new_results["median_ns"] / numpy_results["median_ns"]) / 100
        positive = +(numpy_results["median_ns"] / new_results["median_ns"]) / 100
        score = negative if new_results["median_ns"] >= numpy_results["median_ns"] else positive
        if score >= 10:  score = 10
        if score <= -10: score = -10
        scores.append(score)
    # Free memory to counteract OOMs
    gc.collect()
    torch.cuda.empty_cache()
    return scores

# %% [markdown]
# We create the dataset which includes a replica of our prompt. Remember to add reasoning effort of low!

# %%
from datasets import Dataset
dataset = Dataset.from_list([{"prompt" : [{"role": "user", "content": prompt.strip()}], "answer" : 0, "reasoning_effort": "low"}]*1000)
maximum_length = len(tokenizer.apply_chat_template([{"role": "user", "content": prompt.strip()}], add_generation_prompt = True))
print(maximum_length)
dataset[0]
# Out:
# 130
# {'prompt': [{'content': 'Create a new fast matrix multiplication function using only native Python code.\nYou are given a list of list of numbers.\nOutput your new function in backticks using the format below:\n```python\ndef matmul(A, B):\n    return ...\n```',
#    'role': 'user'}],
#  'answer': 0,
#  'reasoning_effort': 'low'}

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
#
# Now set up GRPO Trainer and all configurations! We also support GSDP, GAPO, Dr GRPO and more! Go to our docs https://docs.unsloth.ai/ for more info!

# %%
max_prompt_length = maximum_length + 1 # + 1 just in case!
max_completion_length = max_seq_length - max_prompt_length

from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    temperature = 1.0,
    learning_rate = 5e-5,
    weight_decay = 0.01,
    warmup_ratio = 0.1,
    lr_scheduler_type = "linear",
    optim = "adamw_8bit",
    logging_steps = 1,
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 2, # Decrease if out of memory
    max_prompt_length = max_prompt_length,
    max_completion_length = max_completion_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 100,
    save_steps = 100,
    report_to = "none", # Can use Weights & Biases
    output_dir = "outputs",

    # For optional training + evaluation
    # fp16_full_eval = True,
    # per_device_eval_batch_size = 4,
    # eval_accumulation_steps = 1,
    # eval_strategy = "steps",
    # eval_steps = 1,
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 2

# %% [markdown]
# And let's run the trainer! If you scroll up, you'll see a table of rewards. The goal is to see the `reward` column increase!
#
# You might have to wait 150 to 200 steps for any action. You'll probably get 0 reward for the first 100 steps. Please be patient!
#
# | Step | Training Loss | reward    | reward_std | completion_length | kl       |
# |------|---------------|-----------|------------|-------------------|----------|
# | 1    | 0.000000      | 0.125000  | 0.000000   | 200.000000        | 0.000000 |
# | 2    | 0.000000      | 0.072375  | 0.248112   | 200.000000        | 0.000000 |
# | 3    | 0.000000      | -0.079000 | 0.163776   | 182.500000        | 0.000005 |

# %%
# For optional training + evaluation
# new_dataset = dataset.train_test_split(test_size = 0.01)

trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        function_works,
        no_cheating,
        correctness_check,
        speed_check,
    ],
    args = training_args,
    train_dataset = dataset,

    # For optional training + evaluation
    # train_dataset = new_dataset["train"],
    # eval_dataset = new_dataset["test"],
)
# Out:
# Unsloth: Switching to float32 training since model cannot work with float16

# %% [markdown]
# And let's train the model!
#
# **NOTE** A T4 free GPU might take 5 minutes for one generation sadly since it's an old GPU - A100 or H100 will be much faster!

# %%
trainer.train()
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': 199998, 'pad_token_id': 200017}.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 2
#    \\   /|    Num examples = 1,000 | Num Epochs = 1 | Total steps = 100
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 1 x 1) = 2
#  "-____-"     Trainable parameters = 1,990,656 of 20,916,747,840 (0.01% trained)
# `generation_config` default values have been modified to match model-specific defaults: {'max_length': 131072}. If this is not desired, please set these values explicitly.
# def matmul(A, B):
#     """
#     Multiply two matrices A and B (lists of lists) using only native Python,
#     without any external libraries.  The function assumes that the matrices
#     are compatible for multiplication.
#
#     Parameters
#     ----------
#     A : List[List[float]]
#         Left matrix of shape (m, n).
#     B : List[List[float]]
#         Right matrix of shape (n, p).
#
#     Returns
#     -------
#     List[List[float]]
#         The product matrix of shape (m, p).
#     """
#     # number of columns in A must equal number of rows in B
#     n = len(A[0])
#     # Transpose B to improve cache locality (optional)
#     B_T = list(zip(*B))            # each element is a tuple of a column
#     result = []
#     for row in A:
#         new_row = []
#         for col in B_T:
#             # compute dot product of row (from A) and column (from B)
#             new_row.append(sum(a*b for a, b in zip(row, col)))
#         result.append(new_row)
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using a simple triple‑nested loop.
#     A and B are expected to be lists of lists with numeric elements.
#     No external libraries are used.
#     """
#     n_rows, n_common = len(A), len(A[0]) if A else 0
#     n_cols = len(B[0]) if B else 0
#
#     # Ensure dimensions are compatible
#     if not B or len(B) != n_common:
#         raise ValueError("Incompatible matrix dimensions")
#
#     result = [[0.0] * n_cols for _ in range(n_rows)]
#
#     for i in range(n_rows):
#         for k in range(n_common):
#             aik = A[i][k]
#             for j in range(n_cols):
#                 result[i][j] += aik * B[k][j]
#     return result
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 7:57:32, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>kl</th>
#       <th>rewards / function_works / mean</th>
#       <th>rewards / function_works / std</th>
#       <th>rewards / no_cheating / mean</th>
#       <th>rewards / no_cheating / std</th>
#       <th>rewards / correctness_check / mean</th>
#       <th>rewards / correctness_check / std</th>
#       <th>rewards / speed_check / mean</th>
#       <th>rewards / speed_check / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>5.860214</td>
#       <td>0.002184</td>
#       <td>260.500000</td>
#       <td>200.000000</td>
#       <td>321.000000</td>
#       <td>0.000000</td>
#       <td>260.500000</td>
#       <td>200.000000</td>
#       <td>321.000000</td>
#       <td>0.001558</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>0.000000</td>
#       <td>-0.139786</td>
#       <td>0.002183</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>1.405377</td>
#       <td>0.205026</td>
#       <td>297.000000</td>
#       <td>200.000000</td>
#       <td>394.000000</td>
#       <td>0.000000</td>
#       <td>297.000000</td>
#       <td>200.000000</td>
#       <td>394.000000</td>
#       <td>0.001605</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>0.000000</td>
#       <td>-4.594623</td>
#       <td>0.205026</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>-0.003606</td>
#       <td>0.178821</td>
#       <td>334.000000</td>
#       <td>309.000000</td>
#       <td>359.000000</td>
#       <td>0.000000</td>
#       <td>334.000000</td>
#       <td>309.000000</td>
#       <td>359.000000</td>
#       <td>0.000510</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>0.000000</td>
#       <td>-6.003606</td>
#       <td>0.178821</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>3.867002</td>
#       <td>0.232169</td>
#       <td>369.500000</td>
#       <td>312.000000</td>
#       <td>427.000000</td>
#       <td>0.000000</td>
#       <td>369.500000</td>
#       <td>312.000000</td>
#       <td>427.000000</td>
#       <td>0.000142</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>0.000000</td>
#       <td>-2.132998</td>
#       <td>0.232169</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>-0.000000</td>
#       <td>2.636429</td>
#       <td>0.190505</td>
#       <td>204.500000</td>
#       <td>172.000000</td>
#       <td>237.000000</td>
#       <td>0.000000</td>
#       <td>204.500000</td>
#       <td>172.000000</td>
#       <td>237.000000</td>
#       <td>0.000514</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>0.000000</td>
#       <td>-3.363571</td>
#       <td>0.190505</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000200</td>
#       <td>4.108238</td>
#       <td>0.000967</td>
#       <td>205.500000</td>
#       <td>198.000000</td>
#       <td>213.000000</td>
#       <td>0.000000</td>
#       <td>205.500000</td>
#       <td>198.000000</td>
#       <td>213.000000</td>
#       <td>0.001060</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>0.000000</td>
#       <td>-1.891762</td>
#       <td>0.000967</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>5.434578</td>
#       <td>0.028146</td>
#       <td>210.000000</td>
#       <td>178.000000</td>
#       <td>242.000000</td>
#       <td>0.000000</td>
#       <td>210.000000</td>
#       <td>178.000000</td>
#       <td>242.000000</td>
#       <td>0.006052</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>0.000000</td>
#       <td>-0.565422</td>
#       <td>0.028147</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>3.397164</td>
#       <td>0.429915</td>
#       <td>314.500000</td>
#       <td>267.000000</td>
#       <td>362.000000</td>
#       <td>0.000000</td>
#       <td>314.500000</td>
#       <td>267.000000</td>
#       <td>362.000000</td>
#       <td>0.019459</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>0.000000</td>
#       <td>-2.602836</td>
#       <td>0.429915</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>-11.786570</td>
#       <td>14.443972</td>
#       <td>412.000000</td>
#       <td>187.000000</td>
#       <td>637.000000</td>
#       <td>0.500000</td>
#       <td>187.000000</td>
#       <td>187.000000</td>
#       <td>187.000000</td>
#       <td>0.017343</td>
#       <td>-0.500000</td>
#       <td>2.121320</td>
#       <td>-9.500000</td>
#       <td>14.849242</td>
#       <td>2.000000</td>
#       <td>2.828427</td>
#       <td>-3.786570</td>
#       <td>5.355018</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>5.606992</td>
#       <td>0.056183</td>
#       <td>483.500000</td>
#       <td>362.000000</td>
#       <td>605.000000</td>
#       <td>0.000000</td>
#       <td>483.500000</td>
#       <td>362.000000</td>
#       <td>605.000000</td>
#       <td>0.013118</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>0.000000</td>
#       <td>-0.393008</td>
#       <td>0.056183</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>5.016361</td>
#       <td>0.330143</td>
#       <td>332.500000</td>
#       <td>308.000000</td>
#       <td>357.000000</td>
#       <td>0.000000</td>
#       <td>332.500000</td>
#       <td>308.000000</td>
#       <td>357.000000</td>
#       <td>0.006378</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>0.000000</td>
#       <td>-0.983639</td>
#       <td>0.330143</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000100</td>
#       <td>4.225897</td>
#       <td>0.857006</td>
#       <td>346.500000</td>
#       <td>228.000000</td>
#       <td>465.000000</td>
#       <td>0.000000</td>
#       <td>346.500000</td>
#       <td>228.000000</td>
#       <td>465.000000</td>
#       <td>0.053543</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>0.000000</td>
#       <td>-1.774103</td>
#       <td>0.857006</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000000</td>
#       <td>3.993622</td>
#       <td>0.048897</td>
#       <td>254.000000</td>
#       <td>226.000000</td>
#       <td>282.000000</td>
#       <td>0.000000</td>
#       <td>254.000000</td>
#       <td>226.000000</td>
#       <td>282.000000</td>
#       <td>0.010422</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>4.000000</td>
#       <td>0.000000</td>
#       <td>-2.006378</td>
#       <td>0.048897</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>-9.451910</td>
#       <td>17.745678</td>
#       <td>265.500000</td>
#       <td>228.000000</td>
#       <td>303.000000</td>
#       <td>0.000000</td>
#       <td>265.500000</td>
#       <td>228.000000</td>
#       <td>303.000000</td>
#       <td>0.004942</td>
#       <td>-0.500000</td>
#       <t
# Streaming output truncated to the last 5000 lines.
#     The function returns the resulting matrix as a list of lists.
#     """
#     # Dimensions
#     n, m = len(A), len(A[0])          # A is n×m
#     p, q = len(B), len(B[0])          # B is p×q
#     if m != p:
#         raise ValueError("Incompatible dimensions for matrix multiplication")
#
#     # Initialize result matrix (n×q) with zeros
#     result = [[0.0] * q for _ in range(n)]
#
#     # Perform the multiplication
#     for i in range(n):
#         for k in range(m):                # iterate over shared dimension
#             aik = A[i][k]
#             if aik == 0:                  # skip zero entries for speed
#                 continue
#             row_b = B[k]
#             for j in range(q):
#                 result[i][j] += aik * row_b[j]
#
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using a straightforward triple loop.
#     A and B must be lists of lists (matrices) of compatible dimensions.
#     """
#     n, m = len(A), len(A[0])          # A: n×m
#     p = len(B[0])                     # B: m×p
#     # initialize result matrix C with zeros
#     C = [[0.0] * p for _ in range(n)]
#     # perform multiplication
#     for i in range(n):
#         rowA = A[i]
#         for k in range(m):
#             aik = rowA[k]
#             if aik:  # skip zero entries to save time
#                 rowB = B[k]
#                 for j in range(p):
#                     C[i][j] += aik * rowB[j]
#     return C
# def matmul(A, B):
#     # A: (m x n), B: (n x p)
#     m, n = len(A), len(A[0])
#     # determine size of B
#     p = len(B[0])
#     # initialize result matrix with zeros
#     C = [[0.0] * p for _ in range(m)]
#     # faster local variable binding
#     for i in range(m):
#         row_a = A[i]
#         row_c = C[i]
#         for k in range(n):
#             aik = row_a[k]
#             if aik:
#                 row_bk = B[k]
#                 for j in range(p):
#                     row_c[j] += aik * row_bk[j]
#     return C
# def matmul(A, B):
#     """
#     Multiplies two matrices A and B using only native Python (lists of lists).
#     A: list of list of numbers, shape (m, n)
#     B: list of list of numbers, shape (n, p)
#     Returns matrix of shape (m, p).
#     """
#     m, n = len(A), len(A[0])
#     p = len(B[0])
#
#     # Pre‑compute column slices of B to avoid repeated indexing
#     B_cols = [[B[row][col] for row in range(len(B))] for col in range(p)]
#
#     result = []
#     for i in range(m):
#         row = []
#         for j in range(p):
#             s = 0
#             for k in range(n):
#                 s += A[i][k] * B_cols[j][k]
#             row.append(s)
#         result.append(row)
#     return result
# def matmul(A, B):
#     n = len(A)
#     m = len(B[0])
#     p = len(B)
#     # Initialize the result matrix with zeros
#     C = [[0.0] * m for _ in range(n)]
#     for i in range(n):
#         # Precompute the row of A for quicker access
#         row = A[i]
#         for k in range(p):
#             a = row[k]
#             if a:
#                 # Update all columns of the current row in C
#                 bk = B[k]
#                 for j in range(m):
#                     C[i][j] += a * bk[j]
#     return C
# def matmul(A, B):
#     # A and B are lists of lists (matrices) with dimensions
#     # A: m x k, B: k x n
#     m = len(A)
#     n = len(B[0])
#     k = len(B)
#     # Initialize result matrix C with zeros
#     C = [[0.0 for _ in range(n)] for _ in range(m)]
#     # Fast multiplication using a simple loop (still O(m*k*n))
#     for i in range(m):
#         for j in range(n):
#             s = 0.0
#             for p in range(k):
#                 s += A[i][p] * B[p][j]
#             C[i][j] = s
#     return C
# def matmul(A, B):
#     """
#     Compute the product of two matrices A and B using only native Python.
#     A and B are expected to be lists of lists containing numeric values.
#     """
#     # Dimensions
#     n = len(A)          # rows in A
#     m = len(B[0])      # columns in B
#     p = len(B)         # columns in A / rows in B
#
#     # Initialize result matrix with zeros
#     result = [[0] * m for _ in range(n)]
#
#     for i in range(n):
#         for k in range(p):
#             if A[i][k] == 0:
#                 continue
#             aik = A[i][k]
#             for j in range(m):
#                 result[i][j] += aik * B[k][j]
#
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using pure Python.
#
#     A and B are expected to be lists of lists.
#     The function assumes that the number of columns in A equals the number of rows in B.
#
#     Parameters
#     ----------
#     A : list[list[float]]
#         The left matrix.
#     B : list[list[float]]
#         The right matrix.
#
#     Returns
#     -------
#     list[list[float]]
#         The product matrix A * B.
#     """
#     # Get dimensions
#     n = len(A)            # number of rows in A
#     m = len(A[0])         # number of columns in A (and rows in B)
#     p = len(B[0])         # number of columns in B
#
#     # Transpose B for better cache locality
#     B_T = [list(col) for col in zip(*B)]
#
#     # Prepare the result matrix
#     result = [[0.0 for _ in range(p)] for _ in range(n)]
#
#     for i in range(n):          # iterate over rows of A
#         row_a = A[i]
#         for j in range(p):      # iterate over columns of B
#             # Compute dot product of A[i] and B_T[j]
#             s = 0.0
#             for k in range(m):
#                 s += row_a[k] * B_T[j][k]
#             result[i][j] = s
#
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B.
#
#     Args:
#         A (list of list of numbers): First matrix (m x n).
#         B (list of list of numbers): Second matrix (n x p).
#
#     Returns:
#         list of list of numbers: The product matrix (m x p).
#     """
#     # Basic input validation
#     if not A or not B or not A[0] or not B[0]:
#         return []
#
#     m, n = len(A), len(A[0])
#     n2, p = len(B), len(B[0])
#
#     # Ensure inner dimensions match
#     if n != n2:
#         raise ValueError("Inner matrix dimensions must agree.")
#
#     # Initialize result matrix with zeros
#     result = [[0] * p for _ in range(m)]
#
#     # Perform multiplication in pure Python
#     for i in range(m):
#         for k in range(n):
#             aik = A[i][k]
#             for j in range(p):
#                 result[i][j] += aik * B[k][j]
#
#     return result
# def matmul(A, B):
#     # Validate dimensions
#     if not A or not B:
#         return []
#     m, n = len(A), len(A[0])
#     p, q = len(B), len(B[0])
#     if n != p:
#         raise ValueError("Incompatible dimensions for matrix multiplication")
#
#     # Initialize result matrix with zeros
#     result = [[0] * q for _ in range(m)]
#
#     # Perform multiplication
#     for i in range(m):
#         for k in range(n):
#             aik = A[i][k]
#             for j in range(q):
#                 result[i][j] += aik * B[k][j]
#     return result
# None
# def matmul(A, B):
#     """
#     Multiply two matrices A and B without using external libraries.
#     A and B are expected to be lists of lists (matrices) with compatible dimensions.
#     Returns the product matrix C where C[i][j] = sum_k A[i][k] * B[k][j].
#     """
#     # validate dimensions
#     if not A or not B:
#         raise ValueError("Input matrices cannot be empty.")
#     n_rows_A = len(A)
#     n_cols_A = len(A[0])
#     n_rows_B = len(B)
#     n_cols_B = len(B[0])
#
#     if n_rows_B != n_cols_A:
#         raise ValueError("Number of columns in A must equal number of rows in B.")
#
#     # Initialize result matrix with zeros
#     result = [[0.0 for _ in range(n_cols_B)] for _ in range(n_rows_A)]
#
#     # Fastest possible naive multiplication using native Python
#     for i in range(n_rows_A):
#         a_row = A[i]
#         for k in range(n_cols_A):
#             aik = a_row[k]
#             if aik == 0:
#                 continue  # skip multiplication by zero
#             b_col = [B[k][j] for j in range(n_cols_B)]
#             for j in range(n_cols_B):
#                 result[i][j] += aik * b_col[j]
#
#     return result
# def matmul(A, B):
#     """
#     Multiplies two matrices A and B, where A and B are lists of lists.
#     The function assumes that A[i][j] and B[i][j] are numeric values
#     (int or float).  It uses only native Python constructs, no external
#     libraries such as NumPy.
#
#     Parameters
#     ----------
#     A : list of lists
#         First matrix, of size (m × n).
#     B : list of lists
#         Second matrix, of size (n × p).
#
#     Returns
#     -------
#     list of lists
#         Resulting matrix of size (m × p).
#
#     Example
#     -------
#     >>> A = [[1, 2], [3, 4]]
#     >>> B = [[5, 6], [7, 8]]
#     >>> matmul(A, B)
#     [[19.0, 22.0], [43.0, 50.0]]
#     """
#     if not A or not B:
#         return []
#
#     m = len(A)          # number of rows in A
#     n = len(A[0])      # number of columns in A / rows in B
#     p = len(B[0])      # number of columns in B
#
#     # Prepare output matrix
#     result = [[0.0] * p for _ in range(m)]
#
#     # Perform multiplication
#     for i in range(m):
#         for k in range(n):
#             aik = A[i][k]
#             if aik:          # skip zero values to reduce work
#                 row = result[i]
#                 for j in range(p):
#                     row[j] += aik * B[k][j]
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using pure Python lists.
#
#     Parameters:
#         A (List[List[float]]): First matrix (m x n).
#         B (List[List[float]]): Second matrix (n x p).
#
#     Returns:
#         List[List[float]]: Resulting matrix (m x p).
#     """
#     # Number of rows and columns in the first matrix
#     m = len(A)
#     n = len(A[0]) if A else 0
#
#     # Number of columns in the second matrix
#     p = len(B[0]) if B else 0
#
#     # Quick sanity check
#     if n != len(B):
#         raise ValueError("Incompatible matrix dimensions for multiplication")
#
#     # Pre-transpose B to speed up inner product lookups
#     B_T = [[B[row][col] for row in range(len(B))] for col in range(p)]
#
#     # Result matrix initialization
#     result = [[0.0 for _ in range(p)] for _ in range(m)]
#
#     # Core multiplication loop
#     for i in range(m):
#         row_a = A[i]
#         for j in range(p):
#             # Compute dot product of row i of A and column j of B
#             s = 0.0
#             for k in range(n):
#                 s += row_a[k] * B_T[j][k]
#             result[i][j] = s
#
#     return result
# def matmul(A, B):
#     # Make sure the matrices can be multiplied
#     n_rows = len(A)
#     n_cols = len(B[0])
#     common_dim = len(B)
#
#     if len(A[0]) != common_dim:
#         raise ValueError("Number of columns in A must equal number of rows in B.")
#
#     # Initialize the result matrix with zeros
#     result = [[0] * n_cols for _ in range(n_rows)]
#
#     # Perform multiplication using Python's built‑in loops
#     for i in range(n_rows):
#         for k in range(common_dim):
#             a_val = A[i][k]
#             if a_val:
#                 for j in range(n_cols):
#                     result[i][j] += a_val * B[k][j]
#     return result
# def matmul(A, B):
#     """
#     Multiplies two matrices A and B using only native Python constructs.
#     A and B are expected to be lists of lists with compatible dimensions.
#
#     The function:
#     1. Transposes B once to enable fast column access.
#     2. Uses list comprehensions and generator expressions to compute dot products.
#
#     Complexity: O(n * m * p) for matrices of appropriate sizes.
#     """
#     # Transpose B for cache‑friendly column access
#     B_T = [list(col) for col in zip(*B)]
#
#     # Compute each row of the result
#     result = []
#     for row in A:
#         # Dot product of this row with every column in B
#         result.append([sum(a * b for a, b in zip(row, col)) for col in B_T])
#     return result
# def matmul(A, B):
#     """
#     Multiply two square matrices (or rectangular matrices with compatible shapes) using native Python lists.
#
#     Parameters
#     ----------
#     A : list[list[float]]
#         Left matrix.
#     B : list[list[float]]
#         Right matrix.
#
#     Returns
#     -------
#     list[list[float]]
#         The product matrix A * B.
#     """
#     n = len(A)            # number of rows in A
#     m = len(B[0])         # number of columns in B
#     p = len(B)            # number of rows in B (must match len(A[0]))
#
#     # Initialise result matrix with zeros
#     C = [[0.0] * m for _ in range(n)]
#
#     # Standard triple loop, but with a few micro‑optimisations
#     for i in range(n):
#         ai = A[i]
#         ci = C[i]
#         for k in range(p):
#             aik = ai[k]
#             if aik:              # skip zero entries to save a few multiplications
#                 bk = B[k]
#                 for j in range(m):
#                     ci[j] += aik * bk[j]
#     return C
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using standard O(n^3) algorithm.
#     A and B are lists of lists, representing matrices in row-major form.
#     Returns the product matrix as a new list of lists.
#     Assumes that A's number of columns equals B's number of rows.
#     """
#     n = len(A)            # number of rows in A
#     m = len(A[0])         # number of columns in A (also rows in B)
#     p = len(B[0])         # number of columns in B
#
#     # Initialize result matrix with zeros
#     result = [[0] * p for _ in range(n)]
#
#     for i in range(n):
#         for k in range(m):          # iterate over columns of A / rows of B
#             aik = A[i][k]
#             for j in range(p):
#                 result[i][j] += aik * B[k][j]
#
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B (both given as lists of lists)
#     using a cache-friendly, row-major approach in pure Python.
#     """
#     # Basic sanity checks
#     if not A or not B:
#         return []
#
#     # Dimensions
#     n = len(A)          # rows of A
#     m = len(A[0])       # columns of A
#     p = len(B[0])       # columns of B
#
#     # fast path for square matrices with power-of-2 size
#     # (only for demonstration; the algorithm below works for any size)
#     result = [[0] * p for _ in range(n)]
#
#     # Cache-friendly nested loops
#     for i in range(n):
#         for k in range(m):
#             aik = A[i][k]
#             if aik == 0:
#                 continue
#             for j in range(p):
#                 result[i][j] += aik * B[k][j]
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using only native Python code.
#
#     Parameters
#     ----------
#     A : list of lists of numbers
#         First matrix (m x n).
#     B : list of lists of numbers
#         Second matrix (n x p).
#
#     Returns
#     -------
#     list of lists of numbers
#         Resulting matrix from multiplying A * B (m x p).
#     """
#     # Ensure dimensionality compatibility
#     if not A or not B:
#         raise ValueError("Input matrices must be non-empty.")
#     ncols_A = len(A[0])
#     nrows_B = len(B)
#     if ncols_A != nrows_B:
#         raise ValueError("Number of columns of A must equal number of rows of B.")
#
#     # Initialize result matrix with zeros
#     m = len(A)
#     p = len(B[0])
#     result = [[0.0] * p for _ in range(m)]
#
#     # Multiply
#     for i in range(m):
#         for k in range(ncols_A):
#             aik = A[i][k]
#             if aik == 0:
#                 continue
#             for j in range(p):
#                 result[i][j] += aik * B[k][j]
#     return result
# None
# def matmul(A, B):
#     """
#     Fast matrix multiplication using native Python lists.
#     Args:
#         A: list of lists (m x k)
#         B: list of lists (k x n)
#     Returns:
#         C: list of lists (m x n)
#     """
#     # Transpose B to improve cache locality
#     B_T = [list(col) for col in zip(*B)]
#     C = []
#     for row in A:
#         new_row = []
#         for col in B_T:
#             s = 0.0
#             for a, b in zip(row, col):
#                 s += a * b
#             new_row.append(s)
#         C.append(new_row)
#     return C
# def matmul(A, B):
#     """Multiply two matrices A and B using plain Python lists.
#
#     Args:
#         A: List of lists, where each inner list represents a row of the first matrix.
#         B: List of lists, where each inner list represents a row of the second matrix.
#
#     Returns:
#         A new matrix (list of lists) that is the product of A and B.
#
#     The function assumes that the number of columns in A equals the number of rows in B.
#     """
#     # Determine dimensions
#     rows_a = len(A)
#     cols_a = len(A[0]) if A else 0
#     rows_b = len(B)
#     cols_b = len(B[0]) if B else 0
#
#     # Prepare result matrix with zeros
#     result = [[0] * cols_b for _ in range(rows_a)]
#
#     # Compute product
#     for i in range(rows_a):
#         for k in range(cols_a):
#             aik = A[i][k]
#             if aik == 0:
#                 continue
#             for j in range(cols_b):
#                 result[i][j] += aik * B[k][j]
#     return result
# def matmul(A, B):
#     # Determine dimensions
#     m, n = len(A), len(A[0])
#     p, q = len(B), len(B[0])
#     if n != p:
#         raise ValueError("Inner matrix dimensions must agree.")
#
#     # Initialize result matrix with zeros
#     result = [[0.0] * q for _ in range(m)]
#
#     # Perform standard matrix multiplication
#     for i in range(m):
#         for k in range(n):
#             a_val = A[i][k]
#             # If a_val is 0, skip the inner loop for speed
#             if a_val == 0:
#                 continue
#             for j in range(q):
#                 result[i][j] += a_val * B[k][j]
#     return result
# def matmul(A, B):
#     """Multiply two matrices A and B using plain Python."""
#     n, m = len(A), len(B[0])
#     # Transpose B for faster column access
#     B_T = [[B[r][c] for r in range(len(B))] for c in range(len(B[0]))]
#     result = [[0.0] * m for _ in range(len(A))]
#     for i in range(len(A)):
#         for j in range(m):
#             s = 0.0
#             for k in range(len(A[0])):
#                 s += A[i][k] * B_T[j][k]
#             result[i][j] = s
#     return result
# def matmul(A, B):
#     """
#     Fast matrix multiplication using only native Python code.
#
#     Parameters:
#         A (list of list of numbers): Left matrix (m x n).
#         B (list of list of numbers): Right matrix (n x p).
#
#     Returns:
#         list of list of numbers: Resulting matrix (m x p).
#     """
#     # Dimension checks
#     m, n = len(A), len(A[0])
#     nB, p = len(B), len(B[0])
#     if n != nB:
#         raise ValueError("Inner matrix dimensions must agree.")
#
#     # Transpose B to speed up inner product lookup
#     B_T = [[B[row][col] for row in range(nB)] for col in range(p)]
#
#     result = [[0.0 for _ in range(p)] for _ in range(m)]
#
#     for i in range(m):
#         ai = A[i]
#         for j in range(p):
#             bj = B_T[j]
#             s = 0
#             for k in range(n):
#                 s += ai[k] * bj[k]
#             result[i][j] = s
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using only native Python.
#     A: m x n matrix (list of lists)
#     B: n x p matrix (list of lists)
#     Returns: m x p matrix as list of lists
#     """
#     if not A or not B:
#         return []
#
#     m = len(A)          # number of rows in A
#     n = len(A[0])      # number of columns in A (and rows in B)
#     p = len(B[0])      # number of columns in B
#
#     # Initialize result matrix with zeros
#     result = [[0] * p for _ in range(m)]
#
#     # Perform multiplication
#     for i in range(m):
#         for k in range(n):
#             aik = A[i][k]
#             if aik == 0:
#                 continue          # skip zero entries to save work
#             row_bk = B[k]
#             for j in range(p):
#                 result[i][j] += aik * row_bk[j]
#
#     return result
# def matmul(A, B):
#     # Determine dimensions
#     n_rows_A = len(A)
#     n_cols_A = len(A[0]) if A else 0
#     n_rows_B = len(B)
#     n_cols_B = len(B[0]) if B else 0
#
#     # Check compatibility
#     if n_cols_A != n_rows_B:
#         raise ValueError("Number of columns in A must equal number of rows in B")
#
#     # Prepare result matrix initialized to zeros
#     result = [[0] * n_cols_B for _ in range(n_rows_A)]
#
#     # Perform multiplication
#     for i in range(n_rows_A):
#         for k in range(n_cols_A):
#             aik = A[i][k]
#             if aik == 0:
#                 continue
#             for j in range(n_cols_B):
#                 result[i][j] += aik * B[k][j]
#
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B (given as lists of lists) using only native Python.
#     The function assumes that A has dimensions m x n and B has dimensions n x p, and returns
#     an m x p matrix containing the product.
#
#     Parameters
#     ----------
#     A : list of list of numbers
#         First matrix to multiply.
#     B : list of list of numbers
#         Second matrix to multiply.
#
#     Returns
#     -------
#     list of list of numbers
#         The matrix product A · B.
#     """
#     # Transpose B to enable column access with zip
#     B_cols = list(zip(*B))
#
#     # For each row in A, compute dot products with each column in B
#     result = []
#     for row_a in A:
#         new_row = []
#         for col_b in B_cols:
#             # Compute dot product between row_a and col_b
#             dot = sum(v * w for v, w in zip(row_a, col_b))
#             new_row.append(dot)
#         result.append(new_row)
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using only native Python code.
#     A and B are expected to be square (or rectangular) lists of lists.
#     The function will raise a ValueError if the inner dimensions do not match.
#     """
#     # Ensure the inner dimensions agree.
#     if not A or not B or len(A[0]) != len(B):
#         raise ValueError("Inner dimensions of A and B must agree.")
#
#     n = len(A)       # number of rows in A
#     m = len(B[0])    # number of columns in B
#     k = len(B)       # number of rows in B
#
#     # Pre‑allocate the result matrix filled with zeros
#     C = [[0.0 for _ in range(m)] for _ in range(n)]
#
#     # Perform the multiplication
#     for i in range(n):
#         row_a = A[i]
#         for j in range(m):
#             s = 0.0
#             for l in range(k):
#                 s += row_a[l] * B[l][j]
#             C[i][j] = s
#
#     return C
# def matmul(A, B):
#     # Transpose B for cache-friendly access
#     B_t = list(zip(*B))          # each element is a tuple of the column values
#     n_rows, n_cols, k = len(A), len(B_t), len(A[0])
#     result = [[0.0] * n_cols for _ in range(n_rows)]
#     for i in range(n_rows):
#         ai = A[i]
#         for j in range(n_cols):
#             bj = B_t[j]
#             s = 0.0
#             for k in range(len(ai)):
#                 s += ai[k] * bj[k]
#             result[i][j] = s
#     return result
# def matmul(A, B):
#     # A and B are lists of lists (matrices in row-major form)
#     n = len(A)          # number of rows in A
#     m = len(A[0])       # number of columns in A (same as rows in B)
#     p = len(B[0])       # number of columns in B
#
#     # Initialize result matrix with zeros
#     result = [[0] * p for _ in range(n)]
#
#     for i in range(n):
#         for k in range(m):
#             aik = A[i][k]
#             for j in range(p):
#                 result[i][j] += aik * B[k][j]
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B (lists of lists) and return the result.
#     Assumes that the number of columns in A equals the number of rows in B.
#     """
#     # Dimensions
#     n = len(A)          # rows of A
#     m = len(B[0])       # columns of B
#     p = len(B)          # rows of B / columns of A
#
#     # Initialise result matrix with zeros
#     C = [[0.0] * m for _ in range(n)]
#
#     # Standard O(n^3) multiplication with a few optimisations
#     for i in range(n):
#         Ai = A[i]
#         Ci = C[i]
#         for k in range(p):
#             aik = Ai[k]
#             if aik == 0:
#                 continue
#             Bk = B[k]
#             for j in range(m):
#                 Ci[j] += aik * Bk[j]
#     return C
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using only native Python code.
#
#     Parameters
#     ----------
#     A : list[list[int|float]]
#         Left matrix (n x m).
#     B : list[list[int|float]]
#         Right matrix (m x p).
#
#     Returns
#     -------
#     list[list[float]]
#         The resulting n x p matrix.
#     """
#     # Basic sanity checks
#     if not A or not B or not A[0] or not B[0]:
#         return []
#
#     n, m = len(A), len(A[0])
#     m2, p = len(B), len(B[0])
#     if m != m2:
#         raise ValueError("Number of columns in A must equal number of rows in B")
#
#     # Pre‑allocate result matrix with zeros
#     result = [[0 for _ in range(p)] for _ in range(n)]
#
#     # Standard triple loop for matrix multiplication
#     for i in range(n):
#         for k in range(m):
#             aik = A[i][k]
#             # Skip computation if aik is zero (micro‑optimization)
#             if aik == 0:
#                 continue
#             for j in range(p):
#                 result[i][j] += aik * B[k][j]
#
#     return result
# def matmul(A, B):
#     if not A or not B:
#         return []
#     n = len(A)
#     m = len(B[0])
#     p = len(B)
#     result = [[0]*m for _ in range(n)]
#     for i in range(n):
#         for k in range(p):
#             aik = A[i][k]
#             if aik:
#                 for j in range(m):
#                     result[i][j] += aik * B[k][j]
#     return result
# None
# def matmul(A, B):
#     """
#     Multiply two matrices A and B, where A and B are given as lists of lists of numbers.
#     The function uses only native Python (no NumPy) and assumes the matrices are compatible for multiplication.
#     """
#     # Validate dimensions
#     if not A or not B:
#         raise ValueError("Matrices must not be empty.")
#     rows_a, cols_a = len(A), len(A[0])
#     rows_b, cols_b = len(B), len(B[0])
#     if cols_a != rows_b:
#         raise ValueError("Incompatible dimensions for multiplication.")
#
#     # Pre-initialize result matrix with zeros
#     result = [[0] * cols_b for _ in range(rows_a)]
#
#     # Perform multiplication
#     for i in range(rows_a):
#         for k in range(cols_a):
#             aik = A[i][k]
#             if aik == 0:
#                 continue  # skip unnecessary work
#             for j in range(cols_b):
#                 result[i][j] += aik * B[k][j]
#     return result
# def matmul(A, B):
#     # A and B are lists of lists, representing matrices
#     n, m = len(A), len(B[0])
#     res = [[0] * m for _ in range(n)]
#     for i in range(n):
#         for k in range(len(A[0])):
#             aik = A[i][k]
#             for j in range(m):
#                 res[i][j] += aik * B[k][j]
#     return res
# def matmul(A, B):
#     """
#     Multiply two matrices A and B where A and B are lists of lists.
#     Uses only native Python (no external libraries) and optimizes with
#     local variables and list comprehensions for speed.
#     """
#     # Dimensions
#     n = len(A)          # rows of A
#     m = len(A[0]) if A else 0   # columns of A
#     p = len(B[0]) if B else 0   # columns of B
#
#     # Precompute columns of B for faster access
#     B_cols = [[B[i][j] for i in range(len(B))] for j in range(p)]
#
#     result = [[0] * p for _ in range(n)]
#     for i in range(n):
#         row_a = A[i]
#         for j in range(p):
#             s = 0
#             col_b = B_cols[j]
#             for k in range(m):
#                 s += row_a[k] * col_b[k]
#             result[i][j] = s
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using native Python.
#
#     Parameters:
#     -----------
#     A : list of list of floats/ints    # matrix of shape m x n
#     B : list of list of floats/ints    # matrix of shape n x p
#
#     Returns:
#     --------
#     List of lists of floats/ints representing the product matrix.
#     """
#     # Validate dimensions
#     if not A or not B or not A[0] or not B[0]:
#         return []
#     m, n = len(A), len(A[0])
#     n_b, p = len(B), len(B[0])
#     if n != n_b:
#         raise ValueError("Incompatible dimensions for matrix multiplication")
#
#     # Precompute column lists of B to avoid repeated indexing
#     B_cols = [[B[row][col] for row in range(n_b)] for col in range(p)]
#
#     # Perform multiplication
#     result = [[0] * p for _ in range(m)]
#     for i in range(m):
#         for j in range(p):
#             total = 0
#             for k in range(n):
#                 total += A[i][k] * B_cols[j][k]
#             result[i][j] = total
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using native Python only.
#     A and B are lists of lists containing numeric values.
#     """
#     # Check matrix dimensions
#     if not A or not B or not B[0]:
#         return []
#
#     n = len(A)          # Number of rows in A
#     m = len(A[0])       # Number of columns in A
#     p = len(B[0])       # Number of columns in B
#
#     # Ensure inner dimensions match
#     if len(B) != m:
#         raise ValueError("Inner dimensions must agree.")
#
#     # Prepare result matrix
#     result = [[0] * p for _ in range(n)]
#
#     # Standard triple-loop multiplication
#     for i in range(n):
#         ai = A[i]
#         for k in range(m):
#             aik = ai[k]
#             if aik == 0:
#                 continue
#             bk = B[k]
#             for j in range(p):
#                 result[i][j] += aik * bk[j]
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using only native Python code.
#
#     Parameters
#     ----------
#     A : list of list of numbers
#         First matrix (M x N).
#     B : list of list of numbers
#         Second matrix (N x P). Assumes that the number of columns in A
#         matches the number of rows in B.
#
#     Returns
#     -------
#     list of list of numbers
#         The matrix product (M x P).
#     """
#     # Dimensions
#     m, n = len(A), len(A[0])           # A is m x n
#     n_b, p = len(B), len(B[0])        # B is n_b x p
#
#     if n != n_b:
#         raise ValueError("Number of columns in A must equal number of rows in B.")
#
#     # Prepare result matrix filled with zeros
#     result = [[0.0 for _ in range(p)] for _ in range(m)]
#
#     # Standard triple‑nested loop for matrix multiplication
#     for i in range(m):
#         for k in range(n):          # iterate over columns of A / rows of B
#             aik = A[i][k]
#             if aik == 0:
#                 continue             # skip if element is zero to save work
#             for j in range(p):
#                 result[i][j] += aik * B[k][j]
#
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using only standard Python.
#     A and B are lists of lists where each sublist represents a row.
#     """
#     # Dimensions
#     n_rows = len(A)
#     n_cols = len(B[0])
#     inner = len(A[0])              # should equal len(B)
#
#     # Prepare result matrix
#     result = [[0.0] * n_cols for _ in range(n_rows)]
#
#     # Standard triple‑nested loop; small optimization: pre‑store transposed B
#     B_T = [[B[i][j] for i in range(len(B))] for j in range(n_cols)]
#
#     for i in range(n_rows):
#         a_row = A[i]
#         for j in range(n_cols):
#             # dot product of a_row and B_T[j]
#             s = 0.0
#             for k in range(inner):
#                 s += a_row[k] * B_T[j][k]
#             result[i][j] = s
#     return result
# def matmul(A, B):
#     # A and B are lists of lists (finite sequences of numbers)
#     n = len(A)
#     m = len(B[0])
#     p = len(B)  # common dimension
#     # Result matrix of size n x m
#     result = [[0] * m for _ in range(n)]
#     for i in range(n):
#         ai = A[i]
#         for k in range(p):
#             aik = ai[k]
#             if aik == 0:
#                 continue
#             bk = B[k]
#             for j in range(m):
#                 result[i][j] += aik * bk[j]
#     return result
# def matmul(A, B):
#     # Assumes A and B are square matrices of the same size
#     n = len(A)
#     result = [[0.0 for _ in range(n)] for _ in range(n)]
#     for i in range(n):
#         for k in range(n):
#             aik = A[i][k]
#             for j in range(n):
#                 result[i][j] += aik * B[k][j]
#     return result
# def matmul(A, B):
#     n = len(A)
#     m = len(B[0])
#     p = len(B)
#     # initialize result matrix with zeros
#     result = [[0.0]*m for _ in range(n)]
#     for i in range(n):
#         for k in range(p):
#             aik = A[i][k]
#             if aik == 0:
#                 continue
#             for j in range(m):
#                 result[i][j] += aik * B[k][j]
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B and return the result.
#
#     Parameters
#     ----------
#     A : list of lists of numbers
#         Left-hand side matrix (m × n).
#     B : list of lists of numbers
#         Right-hand side matrix (n × p).
#
#     Returns
#     -------
#     list of lists of numbers
#         The product matrix (m × p).
#
#     Notes
#     -----
#     The function performs a straightforward O(m·n·p) multiplication
#     using only built‑in Python data structures and integer/float
#     arithmetic.  It assumes that:
#       * Each element of A is a list of length n.
#       * Each element of B is a list of length p.
#       * The number of columns in A equals the number of rows in B.
#     """
#     if not A or not B:
#         return []
#
#     # Number of rows and columns in A
#     m = len(A)
#     n = len(A[0])
#     # Number of rows and columns in B
#     nB = len(B)
#     p = len(B[0])
#
#     if n != nB:
#         raise ValueError("Incompatible dimensions for matrix multiplication")
#
#     # Pre‑allocate result matrix with zeros
#     result = [[0] * p for _ in range(m)]
#
#     # Standard triple loop
#     for i in range(m):
#         for k in range(n):
#             aik = A[i][k]
#             # Only add to result if aik is non-zero (optional tiny speedup)
#             if aik:
#                 for j in range(p):
#                     result[i][j] += aik * B[k][j]
#     return result
# def matmul(A, B):
#     """Multiply two matrices A and B using pure Python (no external libraries)."""
#     # Validate dimensions
#     n_rows, n_cols = len(A), len(A[0]) if A else 0
#     m_rows, m_cols = len(B), len(B[0]) if B else 0
#     if n_cols != m_rows:
#         raise ValueError("Incompatible dimensions: A columns must equal B rows.")
#
#     # Initialize result matrix with zeros
#     result = [[0 for _ in range(m_cols)] for _ in range(n_rows)]
#
#     # Standard triple loop matrix multiplication
#     for i in range(n_rows):
#         for k in range(n_cols):
#             aik = A[i][k]
#             for j in range(m_cols):
#                 result[i][j] += aik * B[k][j]
#
#     return result
# None
# def matmul(A, B):
#     """Multiply two matrices A and B (lists of lists) using pure Python."""
#     # Check that the matrices can be multiplied
#     if not A or not B or len(A[0]) != len(B):
#         raise ValueError("Incompatible matrix dimensions.")
#
#     n_rows_a = len(A)
#     n_cols_b = len(B[0])
#     n_shared = len(B)          # also len(A[0])
#
#     # Preallocate result matrix
#     result = [[0.0 for _ in range(n_cols_b)] for _ in range(n_rows_a)]
#
#     # Perform multiplication
#     for i in range(n_rows_a):
#         a_row = A[i]
#         for k in range(n_shared):
#             aik = a_row[k]          # element A[i][k]
#             if aik == 0:
#                 continue
#             b_col = B[k]
#             for j in range(n_cols_b):
#                 result[i][j] += aik * b_col[j]
#
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B.
#     A: list of rows (each row is a list of numbers)
#     B: list of rows (each row is a list of numbers)
#     Returns the matrix product A*B as a new list of rows.
#     """
#     # Number of rows in A and columns in B must be compatible
#     if not A or not B:
#         raise ValueError("Matrices cannot be empty")
#     if len(A[0]) != len(B):
#         raise ValueError("Incompatible dimensions")
#
#     n_rows = len(A)
#     n_cols = len(B[0])
#     n_common = len(B)  # same as len(A[0])
#
#     # Prepare the output matrix with zeros
#     result = [[0] * n_cols for _ in range(n_rows)]
#
#     # Perform multiplication
#     for i in range(n_rows):
#         row_a = A[i]
#         for k in range(n_common):
#             aik = row_a[k]
#             if aik == 0:
#                 continue
#             row_b = B[k]
#             for j in range(n_cols):
#                 result[i][j] += aik * row_b[j]
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using a simple O(n^3) algorithm.
#     Both A and B must be square matrices of the same dimension.
#     """
#     n = len(A)
#     # Initialize result matrix with zeros
#     result = [[0] * n for _ in range(n)]
#     for i in range(n):
#         for k in range(n):
#             aik = A[i][k]
#             for j in range(n):
#                 result[i][j] += aik * B[k][j]
#     return result
# def matmul(A, B):
#     # A and B are assumed to be lists of lists with compatible dimensions.
#     n = len(A)          # number of rows in A
#     m = len(A[0])       # number of columns in A
#     p = len(B[0])       # number of columns in B
#
#     # Validate dimensions
#     if len(B) != m:
#         raise ValueError("Incompatible dimensions: A columns must equal B rows.")
#
#     # Preallocate result matrix with zeros
#     result = [[0.0] * p for _ in range(n)]
#
#     # Core multiplication loop
#     for i in range(n):
#         ai = A[i]
#         ri = result[i]
#         for k in range(m):
#             aik = ai[k]
#             if aik == 0:
#                 continue
#             bk = B[k]
#             for j in range(p):
#                 ri[j] += aik * bk[j]
#     return result
# None
# def matmul(A, B):
#     # Check dimensions
#     if not A or not B:
#         return []
#     n = len(A)
#     m = len(B[0])
#     p = len(B)
#     # Ensure inner dimensions match
#     if len(A[0]) != p:
#         raise ValueError("Inner dimensions must match")
#     # Initialize result matrix
#     result = [[0.0 for _ in range(m)] for _ in range(n)]
#     # Perform multiplication
#     for i in range(n):
#         for k in range(p):
#             aik = A[i][k]
#             if aik == 0:
#                 continue
#             for j in range(m):
# ...
#             for j in range(n):
#                 result[i][j] += aik * B[k][j]
#
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using only native Python code.
#
#     Parameters
#     ----------
#     A : list of lists
#         First matrix. Must be of shape (m, n).
#     B : list of lists
#         Second matrix. Must be of shape (n, p).
#
#     Returns
#     -------
#     list of lists
#         Resulting matrix of shape (m, p).
#     """
#     # Basic shape checks
#     if not A or not B:
#         return []
#
#     # Number of rows in A and B
#     m = len(A)
#     n_A = len(A[0])
#
#     # Verify A is rectangular
#     for row in A:
#         if len(row) != n_A:
#             raise ValueError("Matrix A is not rectangular")
#
#     # Number of rows in B must match columns in A
#     if len(B) != n_A:
#         raise ValueError("Inner dimensions must agree: len(A[0]) == len(B)")
#
#     n_B = len(B[0])
#
#     # Verify B is rectangular
#     for row in B:
#         if len(row) != n_B:
#             raise ValueError("Matrix B is not rectangular")
#
#     # Initialize result matrix with zeros
#     result = [[0.0 for _ in range(n_B)] for _ in range(m)]
#
#     # Standard triple‑nested loop multiplication
#     for i in range(m):
#         for k in range(n_A):
#             aik = A[i][k]  # cache to avoid repeated indexing
#             if aik == 0:
#                 continue  # skip zero entries
#             for j in range(n_B):
#                 result[i][j] += aik * B[k][j]
#
#     return result
# def matmul(A, B):
#     """
#     Multiply two square matrices A and B using only native Python code.
#
#     :param A: List[List[int|float]] – first matrix (m x n)
#     :param B: List[List[int|float]] – second matrix (n x p)
#     :return: List[List[int|float]] – result matrix (m x p)
#     """
#     # Ensure matrices are valid and compatible
#     if not A or not B:
#         return []
#     m, n = len(A), len(A[0])
#     n_b, p = len(B), len(B[0])
#     if n != n_b:
#         raise ValueError("Incompatible matrix dimensions for multiplication.")
#
#     # Initialize result matrix with zeros
#     result = [[0 for _ in range(p)] for _ in range(m)]
#
#     # Perform multiplication
#     for i in range(m):
#         for k in range(n):
#             aik = A[i][k]
#             for j in range(p):
#                 result[i][j] += aik * B[k][j]
#
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using a straightforward algorithm.
#
#     Parameters
#     ----------
#     A : List[List[float]]
#         First matrix (m x n).
#     B : List[List[float]]
#         Second matrix (n x p).
#
#     Returns
#     -------
#     C : List[List[float]]
#         Resulting matrix (m x p).
#     """
#     # Dimensions
#     m = len(A)
#     n = len(A[0])
#     p = len(B[0])
#
#     # Initialize result matrix with zeros
#     C = [[0.0 for _ in range(p)] for _ in range(m)]
#
#     # Standard triple‑loop multiplication
#     for i in range(m):
#         for k in range(n):
#             aik = A[i][k]
#             for j in range(p):
#                 C[i][j] += aik * B[k][j]
#
#     return C
# def matmul(A, B):
#     # Basic validation
#     if not A or not B:
#         return []
#
#     n_rows_A = len(A)
#     n_cols_A = len(A[0])
#     n_rows_B = len(B)
#     n_cols_B = len(B[0])
#
#     # Check dimensions compatibility
#     if n_cols_A != n_rows_B:
#         raise ValueError("Number of columns in A must equal number of rows in B.")
#
#     # Initialize result matrix with zeros
#     C = [[0.0] * n_cols_B for _ in range(n_rows_A)]
#
#     # Perform multiplication
#     for i in range(n_rows_A):
#         for j in range(0, n_cols_B):
#             sum_val = 0.0
#             for k in range(n_cols_A):
#                 sum_val += A[i][k] * B[k][j]
#             C[i][j] = sum_val
#
#     return C
# def matmul(A, B):
#     n, m = len(A), len(B[0])
#     # Result matrix of shape len(A) x len(B[0])
#     result = [[0] * m for _ in range(len(A))]
#     # Transpose B for better cache locality
#     B_T = [[B[j][i] for j in range(len(B))] for i in range(m)]
#     for i in range(len(A)):
#         for k in range(len(A[0])):
#             aik = A[i][k]
#             if aik == 0:
#                 continue
#             row = result[i]
#             b_row = B_T
#             for j in range(m):
#                 row[j] += aik * b_row[j][k]
#     return result
# def matmul(A, B):
#     if not A or not B:
#         return []
#     rows_A, cols_A = len(A), len(A[0])
#     rows_B, cols_B = len(B), len(B[0])
#     if cols_A != rows_B:
#         raise ValueError("Incompatible dimensions for matrix multiplication.")
#     # Initialize result matrix with zeros
#     result = [[0] * cols_B for _ in range(rows_A)]
#     # Perform multiplication
#     for i in range(rows_A):
#         for k in range(cols_A):
#             aik = A[i][k]
#             if aik == 0:
#                 continue
#             for j in range(cols_B):
#                 result[i][j] += aik * B[k][j]
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using plain Python without external libraries.
#     A and B are assumed to be lists of lists with compatible dimensions.
#     """
#     # Dimensions
#     m = len(A)          # rows of A
#     n = len(A[0]) if A else 0  # columns of A / rows of B
#     p = len(B[0]) if B else 0  # columns of B
#
#     # Initialize result matrix with zeros
#     result = [[0.0 for _ in range(p)] for _ in range(m)]
#
#     # Classic O(m*n*p) multiplication loop
#     for i in range(m):
#         for k in range(n):
#             if A[i][k] == 0:
#                 continue  # skip zero entries for a tiny speed boost
#             a_val = A[i][k]
#             for j in range(p):
#                 result[i][j] += a_val * B[k][j]
#     return result
# def matmul(A, B):
#     """
#     Multiply two square or rectangular matrices A and B without using any external libraries.
#     A and B are given as lists of lists, where each sublist represents a row.
#     Returns the resulting matrix as a list of lists.
#     """
#     # Verify compatibility
#     n = len(A)          # number of rows in A
#     p = len(A[0])       # number of columns in A
#     if len(B) != p:
#         raise ValueError("Number of columns in A must equal number of rows in B")
#
#     m = len(B[0])       # number of columns in B
#     # Prepare the result matrix filled with zeros
#     C = [[0] * m for _ in range(n)]
#
#     # Standard triple-nested loop (no optimizations such as Strassen or blocking)
#     for i in range(n):
#         for k in range(p):
#             aik = A[i][k]
#             for j in range(m):
#                 C[i][j] += aik * B[k][j]
#     return C
# def matmul(A, B):
#     # A and B are lists of lists representing matrices.
#     # Assume A is of size m x n and B is of size n x p.
#     m = len(A)
#     n = len(A[0]) if A else 0
#     p = len(B[0]) if B else 0
#
#     # initialize result matrix with zeros
#     C = [[0.0 for _ in range(p)] for _ in range(m)]
#
#     # efficient loop ordering to improve cache usage
#     for i in range(m):
#         Ai = A[i]
#         for k in range(n):
#             aik = Ai[k]
#             if aik == 0:
#                 continue
#             Bk = B[k]
#             for j in range(p):
#                 C[i][j] += aik * Bk[j]
#     return C
# def matmul(A, B):
#     """
#     Multiply two matrices A and B.
#     A and B are lists of lists of numbers.
#     Returns the product matrix as a new list of lists.
#     """
#     # Verify that matrices are compatible
#     n = len(A)          # number of rows in A
#     p = len(A[0]) if A else 0  # number of columns in A
#     m = len(B[0]) if B else 0  # number of columns in B
#
#     if len(B) != p:
#         raise ValueError("Number of columns in A must equal number of rows in B")
#
#     # Pre‑allocate result matrix with zeros
#     result = [[0 for _ in range(m)] for _ in range(n)]
#
#     # Standard O(n^3) multiplication, but iterate in a cache‑friendly order
#     for i in range(n):
#         ai = A[i]
#         for k in range(p):
#             aik = ai[k]
#             if aik == 0:
#                 continue
#             bk = B[k]
#             for j in range(m):
#                 result[i][j] += aik * bk[j]
#     return result
# def matmul(A, B):
#     """Multiply two matrices A and B using native Python only.
#
#     Args:
#         A: List of lists representing the first matrix (m x n).
#         B: List of lists representing the second matrix (n x p).
#
#     Returns:
#         A new matrix (list of lists) representing their product.
#
#     Note:
#         No external libraries (numpy, etc.) are used. The function performs
#         the standard O(m*n*p) multiplication using pure Python loops.
#     """
#     # Validate dimensions
#     if not A or not B or not B[0]:
#         return []
#
#     m = len(A)          # rows of A
#     n = len(A[0])      # cols of A / rows of B
#     p = len(B[0])      # cols of B
#
#     # Initialize result matrix with zeros
#     result = [[0] * p for _ in range(m)]
#
#     for i in range(m):
#         for k in range(n):
#             aik = A[i][k]
#             # Skip multiplication if aik is zero for a slight speedup
#             if aik == 0:
#                 continue
#             for j in range(p):
#                 result[i][j] += aik * B[k][j]
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B (lists of lists) with no external libraries.
#
#     Parameters
#     ----------
#     A : list[list[float]]
#         First matrix of shape (m, n)
#     B : list[list[float]]
#         Second matrix of shape (n, p)
#
#     Returns
#     -------
#     list[list[float]]
#         Resulting matrix of shape (m, p)
#
#     Raises
#     ------
#     ValueError
#         If the inner dimensions of A and B do not match.
#     """
#     # Check that the matrices can be multiplied
#     if len(A) == 0 or len(B) == 0 or len(A[0]) != len(B):
#         raise ValueError("Incompatible dimensions for matrix multiplication.")
#
#     m = len(A)          # rows in A
#     n = len(A[0])       # columns in A / rows in B
#     p = len(B[0])       # columns in B
#
#     # Initialize the result matrix with zeros
#     result = [[0.0] * p for _ in range(m)]
#
#     # Perform the multiplication
#     for i in range(m):
#         for k in range(n):
#             aik = A[i][k]          # element from A
#             for j in range(p):
#                 result[i][j] += aik * B[k][j]
#
#     return result
# def matmul(A, B):
#     # A and B are square matrices given as lists of lists
#     n = len(A)
#     # Ensure B has compatible dimensions
#     assert len(B) == n and all(len(row) == n for row in B)
#     # Pre‑allocate result matrix with zeros
#     result = [[0] * n for _ in range(n)]
#     # Standard O(n³) multiplication loop
#     for i in range(n):
#         ai = A[i]
#         ri = result[i]
#         for k in range(n):
#             aik = ai[k]
#             if aik:                     # skip zero multiplications
#                 bk = B[k]
#                 for j in range(n):
#                     ri[j] += aik * bk[j]
#     return result
# def matmul(A, B):
#     """
#     Multiply two square matrices A and B using only native Python code.
#     Assumes A and B are lists of lists of numbers and that they are square
#     (len(A) == len(A[0]) == len(B) == len(B[0])).
#
#     Returns the product matrix as a new list of lists.
#     """
#     n = len(A)
#     # Pre-allocate result matrix
#     C = [[0.0] * n for _ in range(n)]
#     for i in range(n):
#         for k in range(n):
#             a_val = A[i][k]
#             if a_val == 0:
#                 continue
#             for j in range(n):
#                 C[i][j] += a_val * B[k][j]
#     return C
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using a simple block-based approach to
#     improve cache locality and reduce the number of inner-loop operations.
#     A and B are assumed to be square matrices in the form of list of lists
#     of numbers. The function returns a new matrix (list of lists) that
#     represents the product A * B.
#     """
#     n = len(A)
#     # precompute the transpose of B to improve cache locality
#     Bt = [[B[j][i] for j in range(n)] for i in range(n)]
#     result = [[0.0] * n for _ in range(n)]
#     for i in range(n):
#         ai = A[i]
#         ri = result[i]
#         for j in range(n):
#             s = 0.0
#             bj = Bt[j]
#             for k in range(n):
#                 s += ai[k] * bj[k]
#             ri[j] = s
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B.
#
#     Parameters
#     ----------
#     A : list of list of numbers
#         First matrix (m x n).
#     B : list of list of numbers
#         Second matrix (n x p).
#
#     Returns
#     -------
#     list of list of numbers
#         Resulting matrix (m x p).
#     """
#     # Dimensions
#     m, n = len(A), len(A[0])
#     n2, p = len(B), len(B[0])
#     if n != n2:
#         raise ValueError("Inner matrix dimensions must agree")
#
#     # Preallocate result matrix
#     result = [[0 for _ in range(p)] for _ in range(m)]
#
#     # Compute each element
#     for i in range(m):
#         for j in range(p):
#             s = 0
#             for k in range(n):
#                 s += A[i][k] * B[k][j]
#             result[i][j] = s
#
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B where A and B are lists of lists of numbers.
#     Assumes A is m x n and B is n x p.
#     Returns the resulting m x p matrix.
#     """
#     # Ensure compatible dimensions
#     if not A or not B:
#         return []
#     m, n = len(A), len(A[0])
#     p = len(B[0])
#     # Initialize result matrix
#     result = [[0] * p for _ in range(m)]
#     # Perform multiplication
#     for i in range(m):
#         for k in range(n):
#             aik = A[i][k]
#             for j in range(p):
#                 result[i][j] += aik * B[k][j]
#     return result
# def matmul(A, B):
#     # Get dimensions
#     m = len(A)
#     n = len(A[0]) if A else 0
#     p = len(B[0]) if B else 0
#
#     # Prepare result matrix
#     result = [[0.0] * p for _ in range(m)]
#
#     # Standard triple‑loop multiplication (O(m*n*p))
#     for i in range(m):
#         for k in range(n):
#             aik = A[i][k]
#             for j in range(p):
#                 result[i][j] += aik * B[k][j]
#
#     return result
# def matmul(A, B):
#     """
#     Multiply two matrices A and B using plain Python (no external libraries).
#     A and B are expected to be lists of lists with numeric elements.
#
#     Parameters
#     ----------
#     A : list of list of numbers
#         The first matrix, dimensions m x n.
#     B : list of list of numbers
#         The second matrix, dimensions n x p.
#
#     Returns
#     -------
#     list of list of numbers
#         The product matrix C with dimensions m x p.
#
#     Raises
#     ------
#     ValueError
#         If the inner dimensions of A and B do not match.
#     """
#     # Validate that A and B are non-empty matrices
#     if not A or not B:
#         raise ValueError("Input matrices must be non-empty.")
#
#     # Number of rows in A
#     m = len(A)
#     # Number of columns in B - need to be consistent across all rows of B
#     p = len(B[0])
#
#     # Verify that A's number of columns equals B's number of rows
#     n = len(A[0])
#     if n != len(B):
#         raise ValueError(f"Inner dimensions do not match: A is {m}x{n}, B is {len(B)}x{p}.")
#
#     # Pre‑allocate result matrix with zeros
#     C = [[0.0] * p for _ in range(m)]
#
#     # Standard triple‑loop multiplication
#     for i in range(m):
#         for k in range(n):
#             aik = A[i][k]
#             for j in range(p):
#                 C[i][j] += aik * B[k][j]
#
#     return C
# def matmul(A, B):
#     # Determine dimensions
#     m = len(A)          # number of rows in A
#     n = len(A[0])      # number of columns in A / rows in B
#     p = len(B[0])      # number of columns in B
#
#     # Initialize result matrix with zeros
#     result = [[0] * p for _ in range(m)]
#
#     # Standard matrix multiplication
#     for i in range(m):
#         for k in range(n):
#             aik = A[i][k]
#             if aik == 0:
#                 continue
#             for j in range(p):
#                 result[i][j] += aik * B[k][j]
#
#     return result
# TrainOutput(global_step=100, training_loss=0.0001529979705810547, metrics={'train_runtime': 28932.3096, 'train_samples_per_second': 0.007, 'train_steps_per_second': 0.003, 'total_flos': 0.0, 'train_loss': 0.0001529979705810547})

# %% [markdown]
# <a name="Inference"></a>
# # Inference
# Now let's try the model we just trained!

# %%
text = tokenizer.apply_chat_template(
    [{"role": "user", "content": prompt}],
    tokenize = False,
    add_generation_prompt = True,
    reasoning_effort = "low",
)

from transformers import TextStreamer
_ = model.generate(
    **tokenizer(text, return_tensors = "pt").to("cuda"),
    temperature = 1.0,
    max_new_tokens = 1024,
    streamer = TextStreamer(tokenizer, skip_prompt = False),
)
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2025-09-30
#
# Reasoning: low
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>user<|message|>Create a new fast matrix multiplication function using only native Python code.
# You are given a list of list of numbers.
# Output your new function in backticks using the format below:
# ```python
# def matmul(A, B):
#     return ...
# ```<|end|><|start|>assistant<|channel|>analysis<|message|>We need to output code. Probably simple implementation using loops. Provide matmul.<|end|><|start|>assistant<|channel|>final<|message|>```python
# def matmul(A, B):
#     # assuming A is of shape (m, n) and B of shape (n, p)
#     m = len(A)
#     n = len(A[0]) if A else 0
#     p = len(B[0]) if B else 0
#
#     # initialize result matrix with zeros
#     C = [[0.0 for _ in range(p)] for _ in range(m)]
#
#     # naive multiplication
#     for i in range(m):
#         for k in range(n):
#             aik = A[i][k]
#             for j in range(p):
#                 C[i][j] += aik * B[k][j]
#     return C
# ```<|return|>

# %% [markdown]
# <a name="Save"></a>
# ### Saving to float16 or MXFP4 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `mxfp4` for MXFP4 (OpenAI's GPT-OSS native precision). We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge and push to hub in mxfp4 4bit format
if False:
    model.save_pretrained_merged("finetuned_model", tokenizer, save_method = "mxfp4")
if False: model.push_to_hub_merged("repo_id/repo_name", tokenizer, token = "hf...", save_method = "mxfp4")

# Merge and push to hub in 16bit
if False:
    model.save_pretrained_merged("finetuned_model", tokenizer, save_method = "merged_16bit")
if False: # Pushing to HF Hub
    model.push_to_hub_merged("hf/gpt-oss-finetune", tokenizer, save_method = "merged_16bit", token = "")

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
